# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("patient.csv")

# %%
data.head()
# Out:
#    age  gender  chest_pain_type  blood_pressure  cholesterol  max_heart_rate  \
# 0   24     1.0                4             250          139             212
# 1   29     0.0                4             132          187             147
# 2   46     0.0                3             271          185             193
# 3   73     NaN                2             102          200             125
# 4   49     1.0                3              91          163             192
#
#    exercise_angina  plasma_glucose  skin_thickness  insulin        bmi  \
# 0                0           108.0            33.0    109.0  37.999303
# 1                0           202.0            42.0      NaN  25.588346
# 2                0           149.0            43.0    102.0  37.892029
# 3                0           105.0            77.0    165.0  18.660241
# 4                0           162.0            31.0    170.0  12.767980
#
#    diabetes_pedigree  hypertension  heart_disease residence_type  \
# ...

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (3734, 16)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


label_encoder = LabelEncoder()
data['residence_type'] = label_encoder.fit_transform(data['residence_type'])
data['smoking_status'] = label_encoder.fit_transform(data['smoking_status'])

scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_scaled)

pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# %%
pca_df.head()
# Out:
#         PC1       PC2
# 0  0.475535  2.598977
# 1  0.155226  1.656416
# 2  0.460574  1.125821
# 3  0.890637 -1.675715
# 4  0.601033  3.262984

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize = (10,7))
plt.title("Patient Clustering")
dend = shc.dendrogram(shc.linkage(pca_df , method = 'ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters = 3 ,linkage = 'ward')

label = cluster.fit_predict(pca_df)

# %%
plt.figure(figsize = (10,7))
plt.scatter(data.iloc[: ,3],data.iloc[:,0], c = label , cmap = 'rainbow')

# %%
# this is not a good clustering that's my first clustering so ya will do better next time
