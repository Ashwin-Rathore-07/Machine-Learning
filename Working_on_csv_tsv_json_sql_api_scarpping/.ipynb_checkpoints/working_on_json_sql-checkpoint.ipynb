# %%
# read more info on pandas documentation about json and sql

# %%
import pandas as pd

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
#can use url for json data
pd.read_json("https://api.github.com/users/hadley/orgs")
# Out:
#                login        id                           node_id  \
# 0              ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1            rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2             rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 3           ropensci   1200269  MDEyOk9yZ2FuaXphdGlvbjEyMDAyNjk=
# 4           rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 5              r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 6        RConsortium  15366137  MDEyOk9yZ2FuaXphdGlvbjE1MzY2MTM3
# 7          tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
# 8              r-lib  22618716  MDEyOk9yZ2FuaXphdGlvbjIyNjE4NzE2
# 9  rstudio-education  34165516  MDEyOk9yZ2FuaXphdGlvbjM0MTY1NTE2
#
#                                              url  \
# 0              https://api.github.com/orgs/ggobi
# 1            https://api.github.com/orgs/rstudio
# 2             https://api.github.com/orgs/rstats
# 3           https://api.github.com/orgs/ropensci
# ...

# %% [markdown]
# #working on sql

# %% [markdown]
# #for working on sql, can use xampp server for making a database or postgreSQL or any other

# %%
#first install mysql.connector through,it help to connect with xampp server
# conda install -c conda-forge mysql-connector-python

# %% [markdown]
# they officially only support SQLAlchemy engines or sqlite3 connections. Other DBAPI2 connectors (like mysql.connector) might work, but they haven’t tested them — so use at your own risk

# %%
import mysql.connector

conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')
pd.read_sql_query("SELECT * FROM city",conn)

# and can use every function which php has
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_27260\2254976920.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'PSE'",conn)
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_27260\3946242588.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'PSE'",conn)
#      ID        Name CountryCode    District  Population
# 0  4074        Gaza         PSE        Gaza      353632
# 1  4075  Khan Yunis         PSE  Khan Yunis      123175
# 2  4076      Hebron         PSE      Hebron      119401
# 3  4077    Jabaliya         PSE  North Gaza      113901
# 4  4078      Nablus         PSE      Nablus      100231
# 5  4079       Rafah         PSE       Rafah       92020
