# %%
class linear_regression:
    def __init__(self):
        self.m = None
        self.b = None
    def fit(self , x_train , y_train):
        num = 0
        den = 0
        for i in range (x_train.shape[0]):
            num = num + ((y_train[i] - y_train.mean())*(x_train[i] - x_train.mean()))
            den = den + ((x_train[i] - x_train.mean())*(x_train[i] - x_train.mean()))
        self.m = num / den
        self.b = y_train.mean() - self.m * x_train.mean()
        print(self.m)
        print(self.b)
    def predict(self , x_test):
        return self.m * x_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = df.iloc[:,0].values
y = df.iloc[: , 1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split ( x , y , test_size = 0.2,random_state=10)

# %%
x_train.shape
# Out:
# (160,)

# %%
lr = linear_regression()

# %%
lr.fit(x_train , y_train)
# Out:
# 0.5623944984550373
# -0.9329694897307057

# %%
x_test
# Out:
# array([7.56, 7.89, 7.28, 7.63, 8.37, 7.48, 5.53, 8.2 , 7.3 , 7.82, 7.69,
#        5.32, 6.97, 6.93, 6.06, 9.16, 7.77, 6.59, 5.42, 6.31, 7.08, 6.68,
#        5.48, 8.09, 5.13, 6.5 , 5.64, 5.12, 5.84, 6.93, 8.71, 7.43, 6.94,
#        6.22, 6.87, 8.15, 6.78, 9.31, 6.07, 7.32])

# %%
y_test
# Out:
# array([3.31, 2.99, 3.16, 3.96, 4.11, 2.83, 2.55, 3.39, 2.94, 3.25, 3.83,
#        1.86, 3.28, 3.04, 2.31, 4.25, 4.06, 2.21, 2.25, 3.18, 2.85, 2.49,
#        1.61, 3.55, 1.37, 3.02, 2.1 , 1.98, 3.26, 2.51, 4.08, 3.33, 3.15,
#        2.14, 2.87, 3.63, 3.11, 4.37, 2.26, 2.99])

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score , mean_absolute_error, mean_squared_error
r2 = r2_score(y_test, y_pred)
print("R² Score:",r2 )
# Out:
# R² Score: 0.7681105472626018

# %%
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.2813149220232318

# %%
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MSE: 0.12398652215181497

# %%
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE: 0.35211719945469144

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
x_test.shape
# Out:
# (40,)

# %%
#adjust r2 score
1-((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7620081932431966

# %%
#if we add irrelevant column than it can possible that r2 score will be increase but adjust r2 score will decrease(high difference ) 
#if we add which is relevant that it will have no high difference the adjust r2 and r2 will be nearly same
